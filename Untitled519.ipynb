# %% [markdown]
# <a href="https://colab.research.google.com/github/arumugapandi76/python-learning/blob/main/Untitled519.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install google-generativeai

# %%
import google.generativeai as genai

genai.configure(api_key="Replace with your key")

model = genai.GenerativeModel('gemini-2.5-flash')
# Out:
# /usr/local/lib/python3.12/dist-packages/google/colab/_import_hooks/_hook_injector.py:55: FutureWarning:
#
# All support for the `google.generativeai` package has ended. It will no longer be receiving
# updates or bug fixes. Please switch to the `google.genai` package as soon as possible.
# See README for more details:
#
# https://github.com/google-gemini/deprecated-generative-ai-python/blob/main/README.md
#
#   loader.exec_module(module)

# %%
response=model.generate_content("Describe Generative AI in 20 words")
print(response.text)
# Out:
# Generative AI learns from data to produce new text, images, audio, and video, automating creation and augmenting human creativity.

# %%
response=model.generate_content("Who is the current prime minister of UK")
print(response.text)
# Out:
# The current Prime Minister of the United Kingdom is **Rishi Sunak**.

# %%
genai.configure(api_key="Replace with your key")

model = genai.GenerativeModel('gemini-3.1-flash-lite-preview')

# %%
response=model.generate_content("Who is the current prime minister of UK")
print(response.text)
# Out:
# The current Prime Minister of the United Kingdom is **Keir Starmer**. He has been in office since July 5, 2024, following the Labour Party's victory in the general election.

# %%
response=model.generate_content("Who is the current chief minister of Tamilnadu")
print(response.text)
# Out:
# The current Chief Minister of Tamil Nadu is **M. K. Stalin**. He assumed office on May 7, 2021.
