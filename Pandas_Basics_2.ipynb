# %% [markdown]
# <a href="https://colab.research.google.com/github/arumugapandi76/python-learning/blob/main/Pandas_Basics_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
bankdata=pd.read_csv("bank-data.csv")

# %%
type(bankdata)
# Out:
# pandas.core.frame.DataFrame

# %%
print(bankdata)
# Out:
#           id  age  gender      region    income married  children  car  \
# 0    ID12101   48  FEMALE  INNER_CITY  17546.00      NO         1   NO
# 1    ID12102   40    MALE        TOWN  30085.10     YES         3  YES
# 2    ID12103   51  FEMALE  INNER_CITY  16575.40     YES         0  YES
# 3    ID12104   23  FEMALE        TOWN  20375.40     YES         3   NO
# 4    ID12105   57  FEMALE       RURAL  50576.30     YES         0   NO
# ..       ...  ...     ...         ...       ...     ...       ...  ...
# 595  ID12696   61  FEMALE  INNER_CITY  47025.00      NO         2  YES
# 596  ID12697   30  FEMALE  INNER_CITY   9672.25     YES         0  YES
# 597  ID12698   31  FEMALE        TOWN  15976.30     YES         0  YES
# 598  ID12699   29    MALE  INNER_CITY  14711.80     YES         0   NO
# 599  ID12700   38    MALE        TOWN  26671.60      NO         0  YES
#
#     save_act current_act mortgage  pep
# 0         NO          NO       NO  YES
# ...

# %%
bankdata.head()
# Out:
#         id  age  gender      region   income married  children  car save_act  \
# 0  ID12101   48  FEMALE  INNER_CITY  17546.0      NO         1   NO       NO
# 1  ID12102   40    MALE        TOWN  30085.1     YES         3  YES       NO
# 2  ID12103   51  FEMALE  INNER_CITY  16575.4     YES         0  YES      YES
# 3  ID12104   23  FEMALE        TOWN  20375.4     YES         3   NO       NO
# 4  ID12105   57  FEMALE       RURAL  50576.3     YES         0   NO      YES
#
#   current_act mortgage  pep
# 0          NO       NO  YES
# 1         YES      YES   NO
# 2         YES       NO   NO
# 3         YES       NO   NO
# 4          NO       NO   NO

# %%
bankdata.head(10)
# Out:
#         id  age  gender      region    income married  children  car save_act  \
# 0  ID12101   48  FEMALE  INNER_CITY  17546.00      NO         1   NO       NO
# 1  ID12102   40    MALE        TOWN  30085.10     YES         3  YES       NO
# 2  ID12103   51  FEMALE  INNER_CITY  16575.40     YES         0  YES      YES
# 3  ID12104   23  FEMALE        TOWN  20375.40     YES         3   NO       NO
# 4  ID12105   57  FEMALE       RURAL  50576.30     YES         0   NO      YES
# 5  ID12106   57  FEMALE        TOWN  37869.60     YES         2   NO      YES
# 6  ID12107   22    MALE       RURAL   8877.07      NO         0   NO       NO
# 7  ID12108   58    MALE        TOWN  24946.60     YES         0  YES      YES
# 8  ID12109   37  FEMALE    SUBURBAN  25304.30     YES         2  YES       NO
# 9  ID12110   54    MALE        TOWN  24212.10     YES         2  YES      YES
#
#   current_act mortgage  pep
# 0          NO       NO  YES
# 1         YES      YES   NO
# ...

# %%
bankdata.tail()
# Out:
#           id  age  gender      region    income married  children  car  \
# 595  ID12696   61  FEMALE  INNER_CITY  47025.00      NO         2  YES
# 596  ID12697   30  FEMALE  INNER_CITY   9672.25     YES         0  YES
# 597  ID12698   31  FEMALE        TOWN  15976.30     YES         0  YES
# 598  ID12699   29    MALE  INNER_CITY  14711.80     YES         0   NO
# 599  ID12700   38    MALE        TOWN  26671.60      NO         0  YES
#
#     save_act current_act mortgage  pep
# 595      YES         YES      YES   NO
# 596      YES         YES       NO   NO
# 597      YES          NO       NO  YES
# 598      YES          NO      YES   NO
# 599       NO         YES      YES  YES

# %%
bankdata.shape
# Out:
# (600, 12)

# %%
bankdata.columns
# Out:
# Index(['id', 'age', 'gender', 'region', 'income', 'married', 'children', 'car',
#        'save_act', 'current_act', 'mortgage', 'pep'],
#       dtype='object')

# %%
bankdata.age.head(5)
# Out:
# 0    48
# 1    40
# 2    51
# 3    23
# 4    57
# Name: age, dtype: int64

# %%
bankdata.describe()
# Out:
#               age        income    children
# count  600.000000    600.000000  600.000000
# mean    42.395000  27524.031217    1.011667
# std     14.424947  12899.468246    1.056752
# min     18.000000   5014.210000    0.000000
# 25%     30.000000  17264.500000    0.000000
# 50%     42.000000  24925.300000    1.000000
# 75%     55.250000  36172.675000    2.000000
# max     67.000000  63130.100000    3.000000

# %%
bankdata.age.describe()
# Out:
# count    600.000000
# mean      42.395000
# std       14.424947
# min       18.000000
# 25%       30.000000
# 50%       42.000000
# 75%       55.250000
# max       67.000000
# Name: age, dtype: float64

# %%
bankdata.age.min()
# Out:
# 18

# %%
bankdata.gender.value_counts()
# Out:
# gender
# FEMALE    300
# MALE      300
# Name: count, dtype: int64

# %%
bankdata.married.value_counts()
# Out:
# married
# YES    396
# NO     204
# Name: count, dtype: int64

# %%
bankdata.region.value_counts()
# Out:
# region
# INNER_CITY    269
# TOWN          173
# RURAL          96
# SUBURBAN       62
# Name: count, dtype: int64

# %%
pd.crosstab(bankdata.region,bankdata.gender)
# Out:
# gender      FEMALE  MALE
# region
# INNER_CITY     131   138
# RURAL           47    49
# SUBURBAN        30    32
# TOWN            92    81

# %%
data1 = bankdata[["id","age","gender","region","income","married"]]
data1.head()
# Out:
#         id  age  gender      region   income married
# 0  ID12101   48  FEMALE  INNER_CITY  17546.0      NO
# 1  ID12102   40    MALE        TOWN  30085.1     YES
# 2  ID12103   51  FEMALE  INNER_CITY  16575.4     YES
# 3  ID12104   23  FEMALE        TOWN  20375.4     YES
# 4  ID12105   57  FEMALE       RURAL  50576.3     YES

# %%
bankdata.iloc[3:6,7:9]
# Out:
#   car save_act
# 3  NO       NO
# 4  NO      YES
# 5  NO      YES

# %%
data3=bankdata.iloc[ : ,5:7]
data3.head()
# Out:
#   married  children
# 0      NO         1
# 1     YES         3
# 2     YES         0
# 3     YES         3
# 4     YES         0

# %%
bankdata.iloc[: ,[1,4,6]]
# Out:
#      age    income  children
# 0     48  17546.00         1
# 1     40  30085.10         3
# 2     51  16575.40         0
# 3     23  20375.40         3
# 4     57  50576.30         0
# ..   ...       ...       ...
# 595   61  47025.00         2
# 596   30   9672.25         0
# 597   31  15976.30         0
# 598   29  14711.80         0
# 599   38  26671.60         0
#
# [600 rows x 3 columns]

# %%
bankdata.iloc[4:6 , :]
# Out:
#         id  age  gender region   income married  children car save_act  \
# 4  ID12105   57  FEMALE  RURAL  50576.3     YES         0  NO      YES
# 5  ID12106   57  FEMALE   TOWN  37869.6     YES         2  NO      YES
#
#   current_act mortgage  pep
# 4          NO       NO   NO
# 5         YES       NO  YES

# %%
bankdata.iloc[4:6 , 3:]
# Out:
#   region   income married  children car save_act current_act mortgage  pep
# 4  RURAL  50576.3     YES         0  NO      YES          NO       NO   NO
# 5   TOWN  37869.6     YES         2  NO      YES         YES       NO  YES

# %%
bankdata.gender=="FEMALE"
# Out:
# 0       True
# 1      False
# 2       True
# 3       True
# 4       True
#        ...
# 595     True
# 596     True
# 597     True
# 598    False
# 599    False
# Name: gender, Length: 600, dtype: bool

# %%
bankdata[bankdata.gender=="FEMALE"]
# Out:
#           id  age  gender      region    income married  children  car  \
# 0    ID12101   48  FEMALE  INNER_CITY  17546.00      NO         1   NO
# 2    ID12103   51  FEMALE  INNER_CITY  16575.40     YES         0  YES
# 3    ID12104   23  FEMALE        TOWN  20375.40     YES         3   NO
# 4    ID12105   57  FEMALE       RURAL  50576.30     YES         0   NO
# 5    ID12106   57  FEMALE        TOWN  37869.60     YES         2   NO
# ..       ...  ...     ...         ...       ...     ...       ...  ...
# 591  ID12692   40  FEMALE  INNER_CITY  31473.90      NO         2   NO
# 594  ID12695   59  FEMALE       RURAL  30971.80     YES         3  YES
# 595  ID12696   61  FEMALE  INNER_CITY  47025.00      NO         2  YES
# 596  ID12697   30  FEMALE  INNER_CITY   9672.25     YES         0  YES
# 597  ID12698   31  FEMALE        TOWN  15976.30     YES         0  YES
#
#     save_act current_act mortgage  pep
# 0         NO          NO       NO  YES
# ...

# %%
bankdata.shape
# Out:
# (600, 12)

# %%
bankdata["bonus"]= bankdata.income+(bankdata.income*0.1)
bankdata.head()
# Out:
#         id  age  gender      region   income married  children  car save_act  \
# 0  ID12101   48  FEMALE  INNER_CITY  17546.0      NO         1   NO       NO
# 1  ID12102   40    MALE        TOWN  30085.1     YES         3  YES       NO
# 2  ID12103   51  FEMALE  INNER_CITY  16575.4     YES         0  YES      YES
# 3  ID12104   23  FEMALE        TOWN  20375.4     YES         3   NO       NO
# 4  ID12105   57  FEMALE       RURAL  50576.3     YES         0   NO      YES
#
#   current_act mortgage  pep     bonus
# 0          NO       NO  YES  19300.60
# 1         YES      YES   NO  33093.61
# 2         YES       NO   NO  18232.94
# 3         YES       NO   NO  22412.94
# 4          NO       NO   NO  55633.93

# %%
bankdata.shape
# Out:
# (600, 13)

# %%
def agegroup(age):
  if age<=40:
    return "young"
  elif age<60:
    return "middle aged"
  else:
    return "old"

# %%
agegroup(20)
# Out:
# 'young'

# %%
bankdata["age_cat"]=bankdata.age.apply(agegroup)
bankdata.head(20)
# Out:
#          id  age  gender      region    income married  children  car  \
# 0   ID12101   48  FEMALE  INNER_CITY  17546.00      NO         1   NO
# 1   ID12102   40    MALE        TOWN  30085.10     YES         3  YES
# 2   ID12103   51  FEMALE  INNER_CITY  16575.40     YES         0  YES
# 3   ID12104   23  FEMALE        TOWN  20375.40     YES         3   NO
# 4   ID12105   57  FEMALE       RURAL  50576.30     YES         0   NO
# 5   ID12106   57  FEMALE        TOWN  37869.60     YES         2   NO
# 6   ID12107   22    MALE       RURAL   8877.07      NO         0   NO
# 7   ID12108   58    MALE        TOWN  24946.60     YES         0  YES
# 8   ID12109   37  FEMALE    SUBURBAN  25304.30     YES         2  YES
# 9   ID12110   54    MALE        TOWN  24212.10     YES         2  YES
# 10  ID12111   66  FEMALE        TOWN  59803.90     YES         0   NO
# 11  ID12112   52  FEMALE  INNER_CITY  26658.80      NO         0  YES
# ...

# %% [markdown]
# data export

# %%
bankdata.to_csv("bank_processing.csv",index=False)

# %%
bankdata.to_json("data.json",orient="columns")
